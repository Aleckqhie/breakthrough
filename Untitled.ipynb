# %% [markdown]
# ghggugkgh

# %%
print ("hello worlsd ")
# Out:
# hello worlsd

# %%
print("enter a verb to complete the sentence ")
print ("i can ___ better than you")
space =input ("enter the verb of your choice ")
print (f"i can {space } better than you")
print ((space+' ')*5)
# Out:
# enter a verb to complete the sentence
# i can ___ better than you
# enter the verb of your choice  eat
# i can eat better than you
# eat eat eat eat eat

# %%
print ("smart fit ")   
age =int(input("what age are you"))
if age<18:
    print ("you are eligible for the teens fitness")
elif (age>=18) and (age<40):
    print("you are eligible for the regular fitness programme ")
else :
    print ("you are eligible for the senior wellness programme")
# Out:
# smart fit
# what age are you 59
# you are eligible for the senior wellness programme

# %%
print ("SMART FIT ")
age = int(input("what is your age"))
medical_condition= input("do you have any medical conditions :yes or no")
if medical_condition=='yes':
    medical_condition=True
elif medical_condition=='no':
    medical_condition=False
#bool medical_condition
if age<18:
    print ("you are eligible for the teens fitness")
elif (age>=18) and (age<40):
    print("you are eligible for the regular fitness programme ")
else :
    print ("you are eligible for the senior wellness programme")
if (age>40) and (medical_condition==True):
    print ("medical clearance form required")
elif (age<40) or (medical_condition==False):
    print ("you can proceed with registration")
else :
    print ("invalid input .please enter 'True'or 'False'")
#membership programme
membership =input("what memebership plan do you have in mind 'Basic'or 'premium':").strip().lower()
if membership== 'basic':
    personal_training=input("would you like personal training: 'yes'or 'no':")
    if personal_training== 'yes':
        print("Basic plan with personal training :$45 per month ")
    else :
        print("Basic plan $30 per month")
elif membership=='premium':
    print ("premium plan:$60 per month")
else :
    print("choose a membership plan  to proceed ")
# Out:
# SMART FIT
# what is your age 45
# do you have any medical conditions :yes or no Basic
# you are eligible for the senior wellness programme
# invalid input .please enter 'True'or 'False'
# what memebership plan do you have in mind 'Basic'or 'premium': Basic
# would you like personal training: 'yes'or 'no': yes
# Basic plan with personal training :$45 per month
